# %%
import os
import sys
sys.path.insert(0, os.path.abspath('..'))

import numpy as np
from matplotlib import pyplot as plt

from module.base.network import Network

# %%
net = Network(10,10,1,[[0,0,0]],[[9,9,0]],[])
net.set_voltage_config([10],[-10],[],0)

# %%
occupations = np.random.randn(100) * 3
potentials = np.reshape(net.calc_potentials(occupations), (10,10))

# %%
plt.figure(figsize=(8,3))
plt.subplot(1,2,1)
plt.title("potentials")
plt.imshow(potentials)
plt.colorbar()
plt.subplot(1,2,2)
plt.title("occupations")
plt.imshow(occupations.reshape((10,10)))
plt.colorbar()
