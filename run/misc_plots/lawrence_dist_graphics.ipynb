# %%
import sys
sys.path.insert(0, "../..")

import numpy as np
from matplotlib import pyplot as plt
plt.style.use('seaborn')

from module.base.network import Network

from module.simulation.meanfield import MeanField
from module.simulation.quick_meanfield2 import QuickMeanField2
from module.simulation.meanfield2 import MeanField2
from module.simulation.set_meanfield2 import SetMeanField2

import module.components.CONST as CONST
from module.components.lawrence_dist import LawrenceDist

from module.components.Adam import Adam
# Out:
# /tmp/ipykernel_321/1503088273.py:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
def set_size(width = "thesis", fraction=1, subplots=(1, 1)):
    if width == 'thesis':
        width_pt = 426.79135
    elif width == 'beamer':
        width_pt = 307.28987
    else:
        width_pt = width

    # Width of figure (in pts)
    fig_width_pt = width_pt * fraction

    # Convert from pt to inches
    inches_per_pt = 1 / 72.27

    # Golden ratio to set aesthetic figure height
    golden_ratio = (5**0.5 - 1) / 2

    # Figure width in inches
    fig_width_in = fig_width_pt * inches_per_pt
    # Figure height in inches
    fig_height_in = fig_height_in = fig_width_in * golden_ratio * (subplots[0] / subplots[1])

    fig_dim = (fig_width_in, fig_height_in)

    return fig_dim

# %%
ldist = LawrenceDist(2, 7)

# %%
probs = ldist.calc_prob(4.43)

# %%
plt.figure(figsize = set_size(fraction = 0.7))
plt.bar(ldist.phase_space, probs)
plt.xlabel("Phase Space $\Omega$")
plt.ylabel("Probability")
plt.title("Lawrence' Distribution with $\\langle n \\rangle = 4.43$")
plt.tight_layout()
plt.savefig("../../output/misc/lawrence_dist.pdf")

# %%
print("var =", 0.43*(1-0.43))
# Out:
# var = 0.2451

# %%
plt.figure(figsize = set_size())
d = np.linspace(0, 1)
plt.plot(d, d * (1-d), label = "$d \\cdot (1 - d)$")
plt.xlabel("Decimals d")
plt.legend()
plt.ylabel("Variance")
plt.title("Variance of Lawrence' Distribution")
plt.tight_layout()
#plt.savefig("../output/misc/lawrence_dist_variance.pdf")
